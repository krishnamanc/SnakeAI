# %%
import os
from stable_baselines3 import PPO
from snakeenv import *

# %%
Log_path = os.path.join('Training', 'Logs')
PPO_path = os.path.join('Training', 'Saved_models')

# %%
env = SnakeEnv()
model = PPO('MlpPolicy',env, verbose=1, tensorboard_log=Log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env.render_mode = 'human'

# %%
env.render_mode = None

# %%
model.learn(total_timesteps=50000)
# Out:
# Logging to Training\Logs\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    fps             | 2516     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 7.15      |
# |    ep_rew_mean          | -106      |
# | time/                   |           |
# |    fps                  | 1065      |
# |    iterations           | 2         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0135094 |
# |    clip_fraction        | 0.122     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.3      |
# |    explained_variance   | -5.91e-05 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.66e+03  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.0194   |
# |    value_loss           | 3.7e+03   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.92        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013894529 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -7.21e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 2.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.7         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015038896 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 2.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 826         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.23        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018268052 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 1.38e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 722         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 1.6e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015325404 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 5.66e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 402         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012001941 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | -4.29e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 345         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 736         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.4        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013025917 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | -1.9e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 471         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.6        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 9           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012672251 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 258         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.7        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012994248 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.2        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 657         |
# |    iterations           | 11          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012397481 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 1.38e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.8        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 97.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.9         |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 12           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0054900805 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.000129     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.8         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00604     |
# |    value_loss           | 71.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.4         |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 13           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0056580817 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.229        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.9         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00794     |
# |    value_loss           | 52           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 680         |
# |    iterations           | 14          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009133608 |
# |    clip_fraction        | 0.0915      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.1        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 15          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004713478 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 39.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 16           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053501427 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.722       |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.9         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00788     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.8         |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 17           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0058141504 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.665       |
# |    explained_variance   | 0.52         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.3         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00821     |
# |    value_loss           | 43.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 677          |
# |    iterations           | 18           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0052245855 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00579     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.5         |
# |    ep_rew_mean          | -105         |
# | time/                   |              |
# |    fps                  | 675          |
# |    iterations           | 19           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0069156503 |
# |    clip_fraction        | 0.0726       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | 0.466        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.6         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00772     |
# |    value_loss           | 42.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.8        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 672         |
# |    iterations           | 20          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005096269 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.672      |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 48          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -106         |
# | time/                   |              |
# |    fps                  | 671          |
# |    iterations           | 21           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0072630597 |
# |    clip_fraction        | 0.0753       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | 0.455        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00802     |
# |    value_loss           | 52.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.9         |
# |    ep_rew_mean          | -104         |
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 22           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0062490515 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00555     |
# |    value_loss           | 42.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26          |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 665         |
# |    iterations           | 23          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008773589 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00774    |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.1        |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 24          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008080471 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00666    |
# |    value_loss           | 64.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | -102         |
# | time/                   |              |
# |    fps                  | 659          |
# |    iterations           | 25           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0069453693 |
# |    clip_fraction        | 0.0874       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.354        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00859     |
# |    value_loss           | 71.4         |
# ------------------------------------------

# %%
env.close()

# %%
model.save(PPO_path)

# %%
env = SnakeEnv()

# %%
model = PPO.load(PPO_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env.render_mode = 'human'

# %%
model.learn(total_timesteps=500)
# Out:
# Logging to Training\Logs\PPO_4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model.learn(total_timesteps=500)
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\ppo\ppo.py:301, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     288 def learn(
#     289     self,
#     290     total_timesteps: int,
#    (...)
#     298     reset_num_timesteps: bool = True,
#     299 ) -> "PPO":
# --> 301     return super(PPO, self).learn(
#     302         total_timesteps=total_timesteps,
#     303         callback=callback,
#     304         log_interval=log_interval,
#     305         eval_env=eval_env,
#     306         eval_freq=eval_freq,
#     307         n_eval_episodes=n_eval_episodes,
#     308         tb_log_name=tb_log_name,
#     309         eval_log_path=eval_log_path,
#     310         reset_num_timesteps=reset_num_timesteps,
#     311     )
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:237, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     233 callback.on_training_start(locals(), globals())
#     235 while self.num_timesteps < total_timesteps:
# --> 237     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     239     if continue_training is False:
#     240         break
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, gym.spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File c:\Users\manch\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# File c:\Pytorch\OpenAIGym\Pygame\Snake\snakeenv.py:169, in SnakeEnv.step(self, action)
#     166 self.info = {}
#     168 if self.render_mode == 'human':
# --> 169     self.render()
#     171 return self.observation, self.reward, self.done, self.info
#
# File c:\Pytorch\OpenAIGym\Pygame\Snake\snakeenv.py:248, in SnakeEnv.render(self, render_mode)
#     244 pygame.draw.rect(self.display, 'WHITE',
#     245                  (self.snake_list[0][0] * 15 + 1, self.snake_list[0][1] * 15 + 1, 13, 13))
#     247 pygame.display.update()
# --> 248 self.clock.tick(FPS)
#     250 # optional
#     251 if self.done:
#
# KeyboardInterrupt:

# %%
env.close()
